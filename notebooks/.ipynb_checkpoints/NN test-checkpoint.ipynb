# %% [markdown]
# # Neural Networks

# %% [markdown]
# We explore here the pist of Neural Networks. As these non-linear models are known of being high-performant, we hope to get better results than with the other models.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from functions import load_data

X_tr, X_te, y_tr, y_te = load_data()

# %%
import tensorflow as tf
from tensorflow.keras import Sequential, activations, initializers, optimizers, metrics, losses
from tensorflow.keras.layers import Dense

# %% [markdown]
# ## A. Single layer

# %% [markdown]
# When we firstly set the learning rate by default 0.01, the validation and training curves oscillated. Thus, we decided to get a lower value for the learning rate and setting it to 0.001.
#
# According to this [website](https://en.wikipedia.org/wiki/Stochastic_gradient_descent), the learning rate of a Stochastic Gradient Descent defines "how big are the steps the gradient descent makes in the direction of the minimum". By taking a smaller value for the learning rate, we allow our curves to be smoother. For the same purpose, we also set to 128 the size of the batches.

# %%
model = Sequential()

model.add(Dense(
    units = 5, # le nombre de neurones de sorties, c est faux ca devrait etre 4
    activation = activations.softmax, # la dernieres couche est toujours une softmax function pour transformer en proba
    
    # Une autre maniere ca serait de mettre tous les poids à 0, pas un probleme quand on est a une seule couche
    # on a vu que lorsque la fonction d activation est une softmax, mieux d utiliser sqrt(1/n) pour la limite de la distribution norm
    # Pourquoi on coupe notre distribution ? pour calibrer les sorties dans un certain range
    #de chaque neurones avant la fonction d activation
    kernel_initializer = initializers.VarianceScaling(scale = 1, 
                                                      distribution = "truncated_normal", 
                                                      seed = 0), #pour avoir des resultats reproductibles quand je runne le code
    input_dim = 48, #egale au nombre de features
    kernel_regularizer = tf.keras.regularizers.l2(0.1) #ajouter une terme de penalisation a la fonction cout selon un alpha = 0.1
)
         )

model.compile(optimizer = optimizers.SGD(learning_rate = (0.001)), #l algorithme qui optimise les poids W et les biais b
              loss = losses.sparse_categorical_crossentropy, # la fonction cout
              metrics = metrics.sparse_categorical_accuracy) # la metrique de performance

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_tr_rescaled = scaler.fit_transform(X_tr) #the gradient descent is sensible to the scale of the data so we standrize
X_te_rescaled = scaler.fit_transform(X_te)

# %%
history = model.fit(
    x = X_tr_rescaled, 
    y = y_tr, 
    validation_split = 0.2, #pourvoir si il y a un surapprentissage
    batch_size = 128, 
    # on entraine pas sur toute le reseaux de données, on cree des batches qui servent a l optimisation des poids
    # on aurait pu en mettre plus car notre reseau c est 200'000 samples
    epochs = 25, #on fait cette technique en envoyant le dataset 25 fois
    shuffle = True, # shuffle the training data at each epoch
    verbose = 0)
# Out:
# 2025-08-25 14:02:34.742253: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2025-08-25 14:02:34.839814: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2025-08-25 14:02:37.430745: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 2, figsize = (10,4))

axes = axes.flatten()

axes[0].plot(history.history["sparse_categorical_accuracy"], label = "train accuracy")
axes[0].plot(history.history["val_sparse_categorical_accuracy"], label = "validation accuracy")
axes[0].set_xlabel("epoch")
axes[0].set_title("Accuracy: {:.2f}%".format(history.history["val_sparse_categorical_accuracy"][-1]*100))
axes[0].legend()

axes[1].plot(history.history["loss"], label = "train loss")
axes[1].plot(history.history["val_loss"], label = "validation loss")
axes[1].set_xlabel("epoch")
axes[1].set_title("Loss: {:.3f}".format(history.history["val_loss"][-1]))
axes[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# This model is not overfitting but get an accuracy of only around 66%, we were expecting more from this kind of model.

# %% [markdown]
# ## B. Multi-layer Neural Network

# %% [markdown]
# Because we are not satisfied with the previous accuracy, we might check if we can improve it by building a much more complex network (which means increasing the number of neurons and layers).
#
# We start by adding one layer followed by a dropout layer. We take the same learning rate for the Stochastic Gradient Descent.

# %%
from tensorflow.keras.layers import Dropout

multi_layer = Sequential()

multi_layer.add(
    Dense(
        units = 128, 
        activation = activations.relu, 
        input_dim = 48, 
        kernel_initializer = initializers.VarianceScaling(scale = 2, seed = 0), #pour eviter que les couches calculent les mm output
        # scale: std = sqrt(scale/n)
        # on a vu que pour les activations relu c est mieux d utiliser 2 que 1
        kernel_regularizer = tf.keras.regularizers.l2(0.1),
        name = "hidden_layer"
    )
)

multi_layer.add(
    Dropout(
        rate = 0.25, # le taux de desactivation de neurone
        seed = 0, # pour avoir des resultats reproductibles
        name = "dropout_layer", 
    )
)

multi_layer.add(
    Dense(
        units = 5, 
        activation = activations.softmax, 
        kernel_initializer = initializers.VarianceScaling(scale = 1, seed=0),
        kernel_regularizer = tf.keras.regularizers.l2(0.1),
        name = "output_layer"
    )
)

# %%
multi_layer.compile(optimizer = optimizers.SGD(learning_rate = (0.001)), 
                loss = losses.sparse_categorical_crossentropy, 
                metrics = metrics.sparse_categorical_accuracy)

# %%
history_2 = multi_layer.fit(
    x=X_tr_rescaled,
    y = y_tr, 
    validation_split = 0.2, 
    batch_size = 128, 
    epochs = 25, 
    shuffle = True, 
    verbose = 0);
# Out:
# 2025-08-25 14:07:34.686873: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2025-08-25 14:07:37.390419: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 2, figsize = (10,4))

axes = axes.flatten()

axes[0].plot(history_2.history["sparse_categorical_accuracy"], label = "train accuracy")
axes[0].plot(history_2.history["val_sparse_categorical_accuracy"], label = "validation accuracy")
axes[0].set_xlabel("epoch")
axes[0].set_title("Accuracy: {:.2f}%".format(history_2.history["val_sparse_categorical_accuracy"][-1]*100))

axes[1].plot(history_2.history["loss"], label = "train loss")
axes[1].plot(history_2.history["val_loss"], label = "validation loss")
axes[1].set_xlabel("epoch")
axes[1].set_title("Loss: {:.3f}".format(history_2.history["val_loss"][-1]))

plt.tight_layout()
plt.show()

# %% [markdown]
# LA IL Y A une risque d overfitting -> soit augmenter le parametre alpha, soit augmenter le nombre de dropout

# %% [markdown]
# We can make the same observation with this model, but we have even a slightly worse precision.
#
# Let's try one last time with a model with 3 hidden layers and dropout layers between each of them. The first layer has 64 neurons and the second 128. Let's cross the fingers.

# %%
layers_3 = Sequential()

layers_3.add(
    Dense(
        units = 64, 
        activation = activations.relu, 
        input_dim = 48, 
        kernel_initializer = initializers.VarianceScaling(scale = 2, seed = 0),
        kernel_regularizer = tf.keras.regularizers.l2(0.1),
        name = "first_layer"
    )
)

layers_3.add(Dropout(rate = 0.25, seed = 0, name = "dropout_layer_1"))

layers_3.add(
    Dense(
        units = 128, 
        activation = activations.relu, 
        kernel_initializer = initializers.VarianceScaling(scale = 2, seed = 0),
        kernel_regularizer = tf.keras.regularizers.l2(0.1),
        name = "second_layer"
    )
)

layers_3.add(Dropout(rate = 0.25, seed = 0, name = "dropout_layer_2"))

layers_3.add(
    Dense(
        units = 5, 
        activation = activations.softmax, 
        kernel_initializer = initializers.VarianceScaling(scale = 1, seed=0),
        kernel_regularizer = tf.keras.regularizers.l2(0.1),
        name = "output_layer"
    )
)

# %%
layers_3.compile(optimizer = optimizers.SGD(learning_rate = (0.001)), 
                loss = losses.sparse_categorical_crossentropy, 
                metrics = metrics.sparse_categorical_accuracy)

# %%
history_3 = layers_3.fit(
    x=X_tr_rescaled,
    y = y_tr, 
    validation_split = 0.2, 
    batch_size = 128, 
    epochs = 25, 
    shuffle = True, 
    verbose = 0);
# Out:
# 2025-08-25 14:12:33.413404: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2025-08-25 14:12:36.460028: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 2, figsize = (10,4))

axes = axes.flatten()

axes[0].plot(history_3.history["sparse_categorical_accuracy"], label = "train accuracy")
axes[0].plot(history_3.history["val_sparse_categorical_accuracy"], label = "validation accuracy")
axes[0].set_xlabel("epoch")
axes[0].set_title("Accuracy: {:.2f}%".format(history_3.history["val_sparse_categorical_accuracy"][-1]*100))

axes[1].plot(history_3.history["loss"], label = "train loss")
axes[1].plot(history_3.history["val_loss"], label = "validation loss")
axes[1].set_xlabel("epoch")
axes[1].set_title("Loss: {:.3f}".format(history_3.history["val_loss"][-1]))

plt.tight_layout()
plt.show()

# %% [markdown]
# Gros overfitting

# %% [markdown]
# We see that the more complex the neuron network, the worst the accuracy.

# %% [markdown]
# ## C. Communication of the results

# %%
y_nn = model.predict(X_te_rescaled)
y_nn = np.argmax(y_nn, axis = 1)
# Out:
# 2025-08-25 14:14:02.628308: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.

# %%
from functions import class_report, confusion_matrix

class_report(y_te, y_nn)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.89      0.52      0.66      7391
#            2       0.61      0.79      0.69     13699
#            3       0.68      0.72      0.70     12292
#            4       0.00      0.00      0.00      1759
#
#     accuracy                           0.67     35141
#    macro avg       0.54      0.51      0.51     35141
# weighted avg       0.66      0.67      0.65     35141

# %%
confusion_matrix(y_te, y_nn, "Neural Network")

# %% [markdown]
# We can see that the results of the Neuron Network are comparable with the ones of the Random Forest classifier, even a bit worse.

# %% [markdown]
# ## D. Saving test accuracy

# %%
acc_nn = (y_nn==y_te).sum()/len(y_te)
np.save("scores & pca components/acc_nn", acc_nn)
